# %%
import pandas as pd

df = pd.read_csv('dataset/robocall-audio-dataset-main/robocall-audio-dataset-main/metadata.csv')

df.columns

df.head()
# Out:
#                                 file_name language  \
# 0  audio-wav-16khz/1112259_normalized.wav       en
# 1    audio-wav-16khz/58345_normalized.wav       en
# 2   audio-wav-16khz/936704_normalized.wav       en
# 3  audio-wav-16khz/1100696_normalized.wav       en
# 4   audio-wav-16khz/807777_normalized.wav       en
#
#                                           transcript  \
# 0  We would like to inform you that there is an o...
# 1  to connect with Apple Support Advisor. Press 2...
# 2  Hello. This call is to inform you that a pre-a...
# 3  one to start your claim. Otherwise, press 2 to...
# 4  Thank you for choosing Hilton Hotels. We would...
#
#                                         case_details  \
# 0                 cease-desist-letter-every1-telecom
# 1           cease-desist-letter-peerless-network-inc
# 2                    cease-desist-letter-one-eye-llc
# 3  cease-desist-letter-business-telecommunication...
# 4  cease-desist-letter-hfa-services-llc-also-dba-...
#
#                                             case_pdf
# 0  pdf_files/pointofnoentry-every1telecomceasedes...
# 1  pdf_files/pointofnoentry-peerlessceasedesistle...
# 2        pdf_files/pointofnoentry-oneeyecdletter.pdf
# 3  pdf_files/pointofnoentry-businesstelecomceased...
# 4  pdf_files/pointofnoentry-hfaservsceasedesistle...

# %%
from datasets import Dataset, Audio
import pandas as pd
import shutil

df = pd.read_csv('dataset/robocall-audio-dataset-main/robocall-audio-dataset-main/metadata.csv')

audio_dataset = Dataset.from_dict({
    "audio": df['file_name'].to_list(),
    "transcript": df['transcript'].to_list(),
    "language" : df['language'].to_list(),
    "case_pdf" : df['case_pdf'].to_list(),
}).cast_column("audio", Audio(sampling_rate=16000,decode=False))
path="dataset/robocall-audio-dataset-main/robocall-audio-dataset-main/"
dest="dataset/malicious/"
for audio in audio_dataset:
    if audio['language']=='en':
        #I need to move to "dataset/malicious" every wav file in path+
        small_path=audio['audio']['path']
        final_path=path+small_path
        shutil.copy(final_path,dest)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 20
#      18 small_path=audio['audio']['path']
#      19 final_path=path+small_path
# ---> 20 shutil.copy(final_path,dest)
#
# File /usr/lib/python3.11/shutil.py:419, in copy(src, dst, follow_symlinks)
#     417 if os.path.isdir(dst):
#     418     dst = os.path.join(dst, os.path.basename(src))
# --> 419 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     420 copymode(src, dst, follow_symlinks=follow_symlinks)
#     421 return dst
#
# File /usr/lib/python3.11/shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254     os.symlink(os.readlink(src), dst)
#     255 else:
# --> 256     with open(src, 'rb') as fsrc:
#     257         try:
#     258             with open(dst, 'wb') as fdst:
#     259                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/robocall-audio-dataset-main/robocall-audio-dataset-main/audio-wav-16khz/s6diZGlyXzJkeGRmYTp0b21jYXQ4MDM4OjE2MzU0NDA4NDgzNDlazL4YQw.gen_Telecall_Communications_Corp._Robocall__SSA-P1-TexasFraud__GovtImpers__normalized.wav'
