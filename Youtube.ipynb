# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/MaliciousCallDetection/

# !cp /content/drive/MyDrive/MaliciousCallDetection/dataset/spectrograms_backup.zip /content

# !unzip /content/spectrograms_backup.zip -d /content


# !git config --global user.email "marinescudragos2014@gmail.com"
# !git config --global user.name "Marinescu Dragos"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/MaliciousCallDetection

# %%
# %cd /content/drive/MyDrive/MaliciousCallDetection/dataset/malicious
# %ls -1 | wc -l
# Out:
# /content/drive/MyDrive/MaliciousCallDetection/dataset/malicious
# 10982

# %%
# !pip install -r /content/drive/MyDrive/MaliciousCallDetection/requirements.txt
from pydub import AudioSegment
import librosa
import soundfile as sf
import io
import os

# %%
# !git add /content/drive/MyDrive/MaliciousCallDetection/Spectrograms.ipynb
# !git commit -m 'added spectrograms back'
# !git push

# %%
# %cd /content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal

# %%
# !yt-dlp -f bestaudio --extract-audio --audio-format wav https://www.youtube.com/watch?v=U05IWKf94sM

# %%
#Here we'll process normal yt audio

#1
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Claude Shannon at MIT： The best master's thesis in history ｜ Neil Gershenfeld and Lex Fridman [kP0zi5lX-Fo].wav")
segment = audio[3000:438000] #0:03-7:18

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Claude Shannon at MIT： The best master's thesis in history ｜ Neil Gershenfeld and Lex Fridman [kP0zi5lX-Fo].wav", audio, 16000)

#2
audio, _ = librosa.load("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Communicate with Confidence： The Blueprint for Mastering Every Conversation [ZUCB3M_1Qp4].wav", sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Communicate with Confidence： The Blueprint for Mastering Every Conversation [ZUCB3M_1Qp4].wav", audio, 16000)

#3
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Elon Musk： Advice for Young People ｜ Lex Fridman Podcast Clips [M-ZH3psUbfU].wav")
segment = audio[3000:478000] #0:03-7:58

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Elon Musk： Advice for Young People ｜ Lex Fridman Podcast Clips [M-ZH3psUbfU].wav", audio, 16000)


#4

audio, _ = librosa.load("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Job Interview   Good Example copy [OVAMb6Kui6A].wav", sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Job Interview   Good Example copy [OVAMb6Kui6A].wav", audio, 16000)

#5
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Joe Rogan ｜ The Morality of CIA Assassins w⧸Annie Jacobsen [stqC8cA-ksQ].wav")
segment=audio[:1051000] #0:00-17:31
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Joe Rogan ｜ The Morality of CIA Assassins w⧸Annie Jacobsen [stqC8cA-ksQ].wav", audio, 16000)


#6
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/President Barack Obama： Between Two Ferns with Zach Galifianakis [UnW3xkHxIEQ].wav")
segment=audio[20000:340000] #0:20-5:40
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/President Barack Obama： Between Two Ferns with Zach Galifianakis [UnW3xkHxIEQ].wav", audio, 16000)

#7
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/The Layers of Intelligence Agencies Involved in Assassinations [56SGGkeC8WI].wav")
segment=audio[3000:746000] #0:03-12:26
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/The Layers of Intelligence Agencies Involved in Assassinations [56SGGkeC8WI].wav", audio, 16000)


#8
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/US debt is growing by $1 trillion every 100 days ｜ Marc Andreessen and Lex Fridman [k_TRiiGqB_w].wav")
segment=audio[3000:530000] #0:03-8:50
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/US debt is growing by $1 trillion every 100 days ｜ Marc Andreessen and Lex Fridman [k_TRiiGqB_w].wav", audio, 16000)

#9
audio, _ = librosa.load("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/When did you know she was the one for you？ (Good Will Hunting) [8SxE_NfUX6w].wav", sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/When did you know she was the one for you？ (Good Will Hunting) [8SxE_NfUX6w].wav", audio, 16000)

#10

audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Learn English quickly with podcast ｜ English learning Conversation ｜ Episode 1 [jNI0fiX4q4A].wav")
segment=audio[5000:1055000] #0:05-17:35
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/Learn English quickly with podcast ｜ English learning Conversation ｜ Episode 1 [jNI0fiX4q4A].wav", audio, 16000)


#11
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/The AI revolution： Myths, risks, and opportunities [U05IWKf94sM].wav")
segment=audio[:1350000] #0:00-22:30
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/The AI revolution： Myths, risks, and opportunities [U05IWKf94sM].wav", audio, 16000)

# %%
from pydub import AudioSegment
import librosa
import soundfile as sf
import io
import os
#1
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/IRS Scammer called the wrong one [U9onI0MzmuI].wav")
segment = audio[34000:]

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/IRS Scammer called the wrong one [U9onI0MzmuI].wav", audio, 16000)

#2
audio=AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Man Receives Call From Scammer and Proceeds to Waste his Time [CuVFcizDwqw].wav")
segment=audio
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Man Receives Call From Scammer and Proceeds to Waste his Time [CuVFcizDwqw].wav", audio, 16000)

#3
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Phone call with HMRC fraudster in UK 2021 [n4iN8fras1Y].wav")
segment = audio[:259000] #4min 19 sec
buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Phone call with HMRC fraudster in UK 2021 [n4iN8fras1Y].wav",audio,16000)

#4
audio1 = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Raging Scammers Transfer $46,000 to me [AKvNo33j5Lw].wav")
segment1 = audio1[144000:260000] #1:44-4:20
buf = io.BytesIO()
segment1.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Raging Scammers Transfer $46,000 to me [AKvNo33j5Lw]_1.wav", audio, 16000)

segment2 = audio1[290000:565000] #4:50-9:25
buf = io.BytesIO()
segment2.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Raging Scammers Transfer $46,000 to me [AKvNo33j5Lw]_2.wav", audio, 16000)
os.remove("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Raging Scammers Transfer $46,000 to me [AKvNo33j5Lw].wav")
#5

audio1 = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/The Cop and The Scammer TWO - Microsoft Technical Support Scam [ZCTKkOjub-E].wav")
segment1 = audio1[20000:135000]  #0:20-2:15

buf = io.BytesIO()
segment1.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/The Cop and The Scammer TWO - Microsoft Technical Support Scam [ZCTKkOjub-E]_1.wav",audio,16000)

segment2 = audio1[172000:410000] #2:52 -6:50

buf = io.BytesIO()
segment2.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/The Cop and The Scammer TWO - Microsoft Technical Support Scam [ZCTKkOjub-E]_2.wav",audio,16000)
os.remove("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/The Cop and The Scammer TWO - Microsoft Technical Support Scam [ZCTKkOjub-E].wav")

#6

audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Phone Scammer Gets Scammed by Police Captain [jXRHb4sCM8c].wav")
segment = audio[:200000]#3:20

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Phone Scammer Gets Scammed by Police Captain [jXRHb4sCM8c].wav", audio, 16000)


#7

audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Installing 100 Viruses - Calling Tech Support Scammers [WKLRKCVar6Y].wav")
segment = audio[251000:740000]  #4:11-12:20

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Installing 100 Viruses - Calling Tech Support Scammers [WKLRKCVar6Y].wav",audio,16000)

#8
audio1 = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Entire Scam Call Center Goes Mad While I Redeem Gift Cards [D7V0Oda3DAA].wav")
segment1 = audio1[107000:410000]  #1:47-6:50

buf = io.BytesIO()
segment1.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Entire Scam Call Center Goes Mad While I Redeem Gift Cards [D7V0Oda3DAA]_1.wav",audio,16000)

segment2 = audio1[446000:833000]  #7:26-13:53

buf = io.BytesIO()
segment2.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Entire Scam Call Center Goes Mad While I Redeem Gift Cards [D7V0Oda3DAA]_2.wav",audio,16000)

segment3 = audio1[876000:984000]  #14:36-16:24

buf = io.BytesIO()
segment3.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Entire Scam Call Center Goes Mad While I Redeem Gift Cards [D7V0Oda3DAA]_3.wav",audio,16000)
os.remove("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Entire Scam Call Center Goes Mad While I Redeem Gift Cards [D7V0Oda3DAA].wav")


#9
audio1 = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Spending All My Money While Scammers Watch (they're furious) [K8weeeK-BPQ].wav")
segment1 = audio1[22000:456000]  #0:22-7:36

buf = io.BytesIO()
segment1.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Spending All My Money While Scammers Watch (they're furious) [K8weeeK-BPQ]_1.wav",audio,16000)

segment2 = audio1[490000:780000]  #8:10-13:00

buf = io.BytesIO()
segment2.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Spending All My Money While Scammers Watch (they're furious) [K8weeeK-BPQ]_2.wav",audio,16000)
os.remove("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Spending All My Money While Scammers Watch (they're furious) [K8weeeK-BPQ].wav")

#10
audio1 = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Scammer Lost His Mind After Failed SYSKEY [698Rm2FV6ik].wav")
segment1 = audio1[:290000]  #0:00-4:50

buf = io.BytesIO()
segment1.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Scammer Lost His Mind After Failed SYSKEY [698Rm2FV6ik]_1.wav",audio,16000)

segment2 = audio1[390000:1055000]  #6:30-17:35

buf = io.BytesIO()
segment2.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Scammer Lost His Mind After Failed SYSKEY [698Rm2FV6ik]_2.wav",audio,16000)
os.remove("/content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/Scammer Lost His Mind After Failed SYSKEY [698Rm2FV6ik].wav")

# %%
# %cd //content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious
# Out:
# /content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious

# %%
# !yt-dlp -f bestaudio --extract-audio --audio-format wav https://www.youtube.com/watch?v=atwTcvM1ZHs
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=atwTcvM1ZHs
# [youtube] atwTcvM1ZHs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] atwTcvM1ZHs: Downloading android vr player API JSON
# [info] atwTcvM1ZHs: Downloading 1 format(s): 251
# [download] Destination: How do Microsoft pop up scammers work (Longest bait-part 1) [atwTcvM1ZHs].webm
# [download] 100% of   16.11MiB in 00:00:04 at 3.37MiB/s
# [ExtractAudio] Destination: How do Microsoft pop up scammers work (Longest bait-part 1) [atwTcvM1ZHs].wav
# Deleting original file How do Microsoft pop up scammers work (Longest bait-part 1) [atwTcvM1ZHs].webm (pass -k to keep)

# %%
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/The Angriest Scammer I've Ever Called - The Hoax Hotel [AuayDyJ1ODI].wav")
segment = audio[20000:]

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/The Angriest Scammer I've Ever Called - The Hoax Hotel [AuayDyJ1ODI].wav",audio,16000)

#2
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/The Scummiest Scam I've Called - The Hoax Hotel [jXv5GKNxcIw].wav")
segment = audio[60000:]

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/The Scummiest Scam I've Called - The Hoax Hotel [jXv5GKNxcIw].wav",audio,16000)


#3
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/Super Scammer Vs. Scammer Spree! - The Hoax Hotel [RmF3Dt74WS0].wav")
segment = audio[25000:-37000]

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/Super Scammer Vs. Scammer Spree! - The Hoax Hotel [RmF3Dt74WS0].wav",audio,16000)

#4
audio1 = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/Super Scammer Vs. Scammer Spree! - The Hoax Hotel [RmF3Dt74WS0].wav")
segment1 = audio1[45000:865000] #0:45-14:25

buf = io.BytesIO()
segment1.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/Super Scammer Vs. Scammer Spree! - The Hoax Hotel [RmF3Dt74WS0]_1.wav",audio,16000)

segment2=audio1[890000:1220000]

buf = io.BytesIO()
segment2.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/Super Scammer Vs. Scammer Spree! - The Hoax Hotel [RmF3Dt74WS0]_2.wav",audio,16000)
os.remove("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/Super Scammer Vs. Scammer Spree! - The Hoax Hotel [RmF3Dt74WS0].wav")

# %%
#Malicious calls used for validation
# %cd /content/drive/MyDrive/MaliciousCallDetection/dataset/validation/malicious
# Out:
# /content/drive/MyDrive/MaliciousCallDetection/dataset/validation/malicious

# %%
# !yt-dlp -f bestaudio --extract-audio --audio-format wav https://www.youtube.com/watch?v=nFT2XNZobUw

# %%
audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/validation/malicious/HOW TO HANDLE A PHONE SCAM [a_RcITCY0dc].wav")
segment = audio[:405000]  #0:00-6:45

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/validation/malicious/HOW TO HANDLE A PHONE SCAM [a_RcITCY0dc].wav",audio,16000)

#2

audio = AudioSegment.from_wav("/content/drive/MyDrive/MaliciousCallDetection/dataset/validation/malicious/SCAMMING the SCAMMER in 5 voices! 😂 He thinks he's on MTV w⧸ Britney Spears! #scambaiting #irlrosie [M_PG9PFZvUk].wav")
segment = audio[12000:]  #0:12-

buf = io.BytesIO()
segment.export(buf, format="wav")
buf.seek(0)

audio, _ = librosa.load(buf, sr=16000)
sf.write("/content/drive/MyDrive/MaliciousCallDetection/dataset/validation/malicious/SCAMMING the SCAMMER in 5 voices! 😂 He thinks he's on MTV w⧸ Britney Spears! #scambaiting #irlrosie [M_PG9PFZvUk].wav",audio,16000)

# %%
#PF detection
# %cd /content/drive/MyDrive/MaliciousCallDetection/dataset/validation/PF_malicious
# Out:
# '/content/drive/MyDrive/MaliciousCallDetection/dataset/validation/PF_malicious'

# %%
# !yt-dlp -f bestaudio --extract-audio --audio-format wav https://www.youtube.com/watch?v=vsp69jYlYsg

# %%
#Download audio , split in 1 minute audios, then generate a random number from 1 to 5 (nr of tts insertions)
#then save the audios in PF_malicious at the end of the loop delete the big old audio file
import librosa
import os
import random
from gtts import gTTS
import tqdm
import soundfile as sf
def process_audio(validation_path):

  scam_phrases = [
        "Suspicious login detected on your bank profile. Confirm your identity now.",
        "A payment of four hundred pounds was authorized from your visa. Press one to dispute.",
        "Your credit card has been flagged for fraudulent international transfers.",
        "To unlock your account, please enter your five-digit secret pin.",
        "Final notice: your mortgage payment is overdue. Connect to an agent.",
        "Federal agents are en route to your address. Connect to an officer immediately.",
        "Your Social Security Number has been linked to a drug trafficking investigation.",
        "Verify your identity to avoid immediate asset seizure and legal prosecution.",
        "A warrant for your arrest has been signed by the local magistrate.",
        "Tax evasion charges have been filed against you. Pay the fine to cancel.",
        "Your network firewall has been breached. System shutdown will begin shortly.",
        "Your device is infected with spyware. Remote access is required for cleanup.",
        "Critical security update failed. Your personal files are now at risk.",
        "We have detected illegal activity originating from your IP address.",
        "Microsoft support alert: your license key has expired. Call us now."
        ]

  print(f"Processing data from '{validation_path}'...")

  for category in ['malicious']:
    dir_path = os.path.join(validation_path, category)

    if not os.path.exists(dir_path):
      continue
    valid_files = [f for f in os.listdir(dir_path) if f.lower().endswith(('.wav', '.mp3'))]

    print(f"\nProcessing category: {category.upper()} ({len(valid_files)} files)")

    for f in tqdm.tqdm(valid_files, desc=f"Procesare {category}"):
      old_path = os.path.join(dir_path, f)
      path=old_path
      audio1 = AudioSegment.from_wav(path)
      seconds=len(audio1)//1000

      idx=1
      audio_name=f.split(".wav")[0].strip()
      start=0
      step=60
      for start in range(0,seconds,step):
        end = min(start + step, seconds)
        audio_segment=audio1[start*1000:end*1000]

        if category=="PF_malicious":
          processed_segment = AudioSegment.empty()
          for i in range(0,len(audio_segment),6000): # I want every 6 seconds to be an insertion
            window = audio_segment[i : i + 6000]
            phrase = random.choice(scam_phrases)
            length=len(phrase)
            phrase=phrase[random.randint(0,length//2):random.randint(length//2+1,length)]

            tts = gTTS(text=phrase, lang='en')
            tts_buf = io.BytesIO()
            tts.write_to_fp(tts_buf)
            tts_buf.seek(0)

            fake_seg = AudioSegment.from_file(tts_buf, format="mp3")

            if len(window) > len(fake_seg):
              p = random.randint(0, len(window) - len(fake_seg))
              window = window[:p] + fake_seg + window[p + len(fake_seg):]
            processed_segment += window

          audio_segment = processed_segment

        buf = io.BytesIO()
        audio_segment.export(buf, format="wav")
        buf.seek(0)

        audio, _ = librosa.load(buf, sr=16000)
        save_file_name = f"{audio_name}_{idx}.wav"
        save_path = os.path.join(validation_path, category, save_file_name)

        idx+=1

        sf.write(save_path,audio,16000)
      try:
        os.remove(old_path)
      except Exception as e:
        print(f"Couldn't delete {old_path}: {e}")




process_audio("/content/drive/MyDrive/MaliciousCallDetection/dataset/train2")
# Out:
# Processing data from '/content/drive/MyDrive/MaliciousCallDetection/dataset/train2'...
#
# Processing category: MALICIOUS (5 files)
# Procesare malicious: 100%|██████████| 5/5 [00:15<00:00,  3.07s/it]

# %%
# %cd PF_malicious
# Out:
# /content/drive/MyDrive/MaliciousCallDetection/dataset/validation/PF_malicious

# %%
# !git add requirements.txt
# !git commit -m 'added yt'
# !git push

# %%
# %mv /content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/malicious/* /content/drive/MyDrive/MaliciousCallDetection/dataset/malicious
# %mv /content/drive/MyDrive/MaliciousCallDetection/dataset/YT_Audio/normal/* /content/drive/MyDrive/MaliciousCallDetection/dataset/normal

# %%
# !mv /content/drive/MyDrive/MaliciousCallDetection/dataset/train2/malicious/* /content/drive/MyDrive/MaliciousCallDetection/dataset/malicious
# !mv /content/drive/MyDrive/MaliciousCallDetection/dataset/train2/normal/* /content/drive/MyDrive/MaliciousCallDetection/dataset/normal
